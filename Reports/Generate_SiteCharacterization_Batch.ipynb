# %% [markdown]
# ## Load libraries

# %%
# Install geospatial dependencies (needed only on a fresh runtime)
# !pip install -q pygeohydro geopandas shapely

import os
import zipfile
from pathlib import Path
from typing import Union, Tuple

import requests
import pandas as pd
import geopandas as gpd
from shapely.geometry import box
from tqdm import tqdm
from pygeohydro import WBD          # HyRiver stack (USGS web-service helpers)

# %% [markdown]
# ## Define parameters for Climate Engine API

# %%
# Base URL & personal API token for Climate Engine
# API parameters
ROOT_URL = "https://api.climateengine.org/"
API_KEY  = (
    "key_here"
)
HEADERS = {"Authorization": API_KEY}
USER_EMAIL = "xxxxx@xxx.com"

# %% [markdown]
# ## Create list of HUC10 watersheds in Colorado and select a subset

# %%
# Retrieve Colorado HUC‑10 geometries with PyGeoHydro and pick a sample set
# Bounding box that covers Colorado (lon/lat, WGS84).
co_bbox: Tuple[float, float, float, float] = (
    -109.060253, 36.992426,  # min lon, min lat
    -102.041524, 41.003444,  # max lon, max lat
)

# Query the USGS Watershed Boundary Dataset
wbd = WBD("huc10")                     # you MUST specify the layer
huc10_gdf: gpd.GeoDataFrame = wbd.bygeom(co_bbox)  # returns GeoDataFrame

# Pick rows 100-125 (inclusive of 100, exclusive of 126) — same as in R
huc10_ids = huc10_gdf["huc10"].iloc[100:126].tolist()
huc10_names = (
    huc10_gdf.set_index("huc10").loc[huc10_ids, "name"].str.slice(0, 35).tolist()
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pygeoogc/core.py:293: UserWarning: Found 1 failed request. Retrying ...
#   resp = self._cleanup_resp(resp, payloads)

# %% [markdown]
# ## Generate Site Characterization reports in batch for each HUC10 watershed

# %%
# Helper that builds parameters & submits a single Site Characterization request
# Climate-Engine request
def generate_report(huc_id: str, name: str) -> dict:
    """
    Call CE /reports/site_characterization/feature_collection for one HUC-10.
    Returns the parsed JSON response.
    """
    endpoint = "reports/site_characterization/feature_collection"
    url = f"{ROOT_URL}{endpoint}"

    params = {
        "user_email": USER_EMAIL,
        "site_name": name,
        "site_type": f"HUC10 {huc_id}",
        "site_description": "Report for Watershed Condition Assessment",
        "mask_ownership": "None",             # change if you want 'BLM', etc.
        "mask_landcover": "True",
        "feature_collection_asset_id": "USGS/WBD/2017/HUC10",
        "sub_choices": huc_id,
        "filter_by": "huc10",
        "batch": "True",
    }

    r = requests.get(url, params=params, headers=HEADERS, timeout=180)
    r.raise_for_status()
    return r.json()

# %%
# Submit requests for each HUC‑10 and collect JSON responses
# Loop over all selected HUCs and collect responses
responses = []
print(f"Requesting {len(huc10_ids)} HUC-10 reports from Climate Engine …")
for huc_id, name in tqdm(list(zip(huc10_ids, huc10_names))):
    responses.append(generate_report(huc_id, name))
# Out:
# Requesting 26 HUC-10 reports from Climate Engine …
# 100%|██████████| 26/26 [03:03<00:00,  7.05s/it]

# %% [markdown]
# ## Parse the results from the API into a dataframe

# %%
# Normalize nested JSON into a tidy DataFrame of download URLs & metadata
# Flatten nested JSON → DataFrame
records = []
for item in responses:
    data = item["Data"]
    records.append(
        {
            "message":          data["Message"],
            "report_link":      data["Report link"],
            "site_description": data["Site description"],
            "site_name":        data["Site name"],
            "site_type":        data["Site type"],
        }
    )

response_df = pd.DataFrame(records)
response_df
# Out:
#              message                                        report_link  \
# 0   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 1   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 2   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 3   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 4   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 5   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 6   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 7   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 8   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 9   Report initiated  https://storage.googleapis.com/reports-site/cu...
# 10  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 11  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 12  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 13  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 14  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 15  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 16  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 17  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 18  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 19  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 20  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 21  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 22  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 23  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 24  Report initiated  https://storage.googleapis.com/reports-site/cu...
# 25  Report initiated  https://storage.googleapis.com/reports-site/cu...
#
#                              site_description  \
# 0   Report for Watershed Condition Assessment
# 1   Report for Watershed Condition Assessment
# 2   Report for Watershed Condition Assessment
# 3   Report for Watershed Condition Assessment
# 4   Report for Watershed Condition Assessment
# 5   Report for Watershed Condition Assessment
# 6   Report for Watershed Condition Assessment
# 7   Report for Watershed Condition Assessment
# 8   Report for Watershed Condition Assessment
# 9   Report for Watershed Condition Assessment
# 10  Report for Watershed Condition Assessment
# 11  Report for Watershed Condition Assessment
# 12  Report for Watershed Condition Assessment
# 13  Report for Watershed Condition Assessment
# 14  Report for Watershed Condition Assessment
# 15  Report for Watershed Condition Assessment
# 16  Report for Watershed Condition Assessment
# 17  Report for Watershed Condition Assessment
# 18  Report for Watershed Condition Assessment
# 19  Report for Watershed Condition Assessment
# 20  Report for Watershed Condition Assessment
# 21  Report for Watershed Condition Assessment
# 22  Report for Watershed Condition Assessment
# 23  Report for Watershed Condition Assessment
# 24  Report for Watershed Condition Assessment
# 25  Report for Watershed Condition Assessment
#
#                               site_name         site_type
# 0                           Sidney Draw  HUC10 1019001702
# 1       Brule Canyon-South Platte River  HUC10 1019001803
# 2                             Sand Draw  HUC10 1025000501
# 3                       City of Venango  HUC10 1025000601
# 4                       Town of Brandon  HUC10 1025000603
# 5                         City of Grant  HUC10 1025000604
# 6                     Little Crow Creek  HUC10 1019000902
# 7             Glade Creek-Dolores River  HUC10 1403000206
# 8         Beaver Creek-San Miguel River  HUC10 1403000303
# 9                       Salt Creek Wash  HUC10 1408010506
# 10           Marble Wash-San Juan River  HUC10 1408020102
# 11  Sangre de Cristo Creek-Trinchera Cr  HUC10 1301000206
# 12                        Pioneer Creek  HUC10 1301000307
# 13           Headwaters La Garita Creek  HUC10 1301000405
# 14             Headwaters Conejos River  HUC10 1301000501
# 15                 Outlet Conejos River  HUC10 1301000504
# 16              Canones Creek-Rio Chama  HUC10 1302010202
# 17                         Beaver Creek  HUC10 1408010113
# 18               Middle Los Pinos River  HUC10 1408010114
# 19         Black Canyon of the Gunnison  HUC10 1402000211
# 20            Smith Fork-Gunnison River  HUC10 1402000212
# 21                           Bear Creek  HUC10 1019000208
# 22  Little Dry Creek-South Platte River  HUC10 1019000209
# 23                     Encampment River  HUC10 1018000204
# 24                          Shell Creek  HUC10 1018001002
# 25                           Dale Creek  HUC10 1019000704

# %% [markdown]
# ## Download all reports

# %%
# Download each ZIP archive and record whether it succeeded
# Download every ZIP and unzip it into Reports_Out/
download_dir = Path("Reports_Out")
download_dir.mkdir(exist_ok=True)

def download_file(url: str, folder: Union[str, Path]) -> Union[Path, None]:
    """Stream-download *url* into *folder*. Return Path or None on failure."""
    fname = folder / Path(url).name
    try:
        with requests.get(url, stream=True, timeout=180) as r:
            r.raise_for_status()
            with open(fname, "wb") as f:
                for chunk in r.iter_content(8192):
                    f.write(chunk)
        return fname
    except requests.RequestException:
        return None

response_df["local_path"] = [
    download_file(u, download_dir) for u in tqdm(response_df.report_link, desc="Downloading")
]
response_df["download_success"] = response_df.local_path.notna()

print("\nDownload summary:")
print(response_df[["site_name", "download_success"]])
# Out:
# Downloading: 100%|██████████| 26/26 [00:08<00:00,  2.93it/s]
# Download summary:
#                               site_name  download_success
# 0                           Sidney Draw              True
# 1       Brule Canyon-South Platte River              True
# 2                             Sand Draw              True
# 3                       City of Venango              True
# 4                       Town of Brandon              True
# 5                         City of Grant              True
# 6                     Little Crow Creek              True
# 7             Glade Creek-Dolores River              True
# 8         Beaver Creek-San Miguel River              True
# 9                       Salt Creek Wash              True
# 10           Marble Wash-San Juan River              True
# 11  Sangre de Cristo Creek-Trinchera Cr              True
# 12                        Pioneer Creek              True
# 13           Headwaters La Garita Creek              True
# 14             Headwaters Conejos River              True
# 15                 Outlet Conejos River              True
# 16              Canones Creek-Rio Chama              True
# 17                         Beaver Creek              True
# 18               Middle Los Pinos River              True
# 19         Black Canyon of the Gunnison              True
# 20            Smith Fork-Gunnison River              True
# 21                           Bear Creek              True
# 22  Little Dry Creek-South Platte River              True
# 23                     Encampment River              True
# 24                          Shell Creek              True
# 25                           Dale Creek              True

# %% [markdown]
# ## Unzip all reports

# %%
# Extract every successfully downloaded ZIP into its own folder
# Unzip
for zpath in response_df.loc[response_df.download_success, "local_path"]:
    out_dir = zpath.with_suffix("")  # strip .zip
    out_dir.mkdir(exist_ok=True)
    with zipfile.ZipFile(zpath) as zf:
        zf.extractall(out_dir)
    print(f"✓ Extracted {zpath.name} → {out_dir}")

print("\nAll done! Reports are in ./Reports_Out/")
# Out:
# ✓ Extracted sidney_draw.zip → Reports_Out/sidney_draw
# ✓ Extracted brule_canyon-south_platte_river.zip → Reports_Out/brule_canyon-south_platte_river
# ✓ Extracted sand_draw.zip → Reports_Out/sand_draw
# ✓ Extracted city_of_venango.zip → Reports_Out/city_of_venango
# ✓ Extracted town_of_brandon.zip → Reports_Out/town_of_brandon
# ✓ Extracted city_of_grant.zip → Reports_Out/city_of_grant
# ✓ Extracted little_crow_creek.zip → Reports_Out/little_crow_creek
# ✓ Extracted glade_creek-dolores_river.zip → Reports_Out/glade_creek-dolores_river
# ✓ Extracted beaver_creek-san_miguel_river.zip → Reports_Out/beaver_creek-san_miguel_river
# ✓ Extracted salt_creek_wash.zip → Reports_Out/salt_creek_wash
# ✓ Extracted marble_wash-san_juan_river.zip → Reports_Out/marble_wash-san_juan_river
# ✓ Extracted sangre_de_cristo_creek-trinchera_cr.zip → Reports_Out/sangre_de_cristo_creek-trinchera_cr
# ✓ Extracted pioneer_creek.zip → Reports_Out/pioneer_creek
# ✓ Extracted headwaters_la_garita_creek.zip → Reports_Out/headwaters_la_garita_creek
# ✓ Extracted headwaters_conejos_river.zip → Reports_Out/headwaters_conejos_river
# ✓ Extracted outlet_conejos_river.zip → Reports_Out/outlet_conejos_river
# ✓ Extracted canones_creek-rio_chama.zip → Reports_Out/canones_creek-rio_chama
# ✓ Extracted beaver_creek.zip → Reports_Out/beaver_creek
# ✓ Extracted middle_los_pinos_river.zip → Reports_Out/middle_los_pinos_river
# ✓ Extracted black_canyon_of_the_gunnison.zip → Reports_Out/black_canyon_of_the_gunnison
# ✓ Extracted smith_fork-gunnison_river.zip → Reports_Out/smith_fork-gunnison_river
# ✓ Extracted bear_creek.zip → Reports_Out/bear_creek
# ✓ Extracted little_dry_creek-south_platte_river.zip → Reports_Out/little_dry_creek-south_platte_river
# ✓ Extracted encampment_river.zip → Reports_Out/encampment_river
# ✓ Extracted shell_creek.zip → Reports_Out/shell_creek
# ✓ Extracted dale_creek.zip → Reports_Out/dale_creek
#
# All done! Reports are in ./Reports_Out/
